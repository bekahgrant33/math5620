# %% [markdown]
# # Reordering nodes
#
# $$
# \frac{1}{h^2}
# \cdot
# \begin{bmatrix}
# -h & h & ...& ..& 0\\
# 1 & 2 & 1& ...& 0\\
# .&... &...&...& 0\\
# 0 & ...& 1 & 2 & \frac{1}{h^{2}}\\
# \end{bmatrix}
#
#  \cdot
#
# \begin{bmatrix}
# U_{0}\\
# U_{1}\\
# ...\\
# U_{m}\\
# U_{m+1}
# \end{bmatrix}
#
# =
#
# \begin{bmatrix}
# f(x_{1}) - \frac{\alpha}{u^{2}}\\
# f(x_{2})\\
# ...\\
# f(x_{m+1})\\
# f(x_{m}) - \frac{\beta}{u^{2}}\\
# \end{bmatrix} $$
#
#
# Even/odd reorder
#
# ODD
#
# $$\frac{U_{j-1} - 2U_j + U_{j+1}}{h^2} = f(x_{j})$$
#
# j = 1
#
# $$\frac{1}{h^2}(U_{0} - 2U_{1}+ U_{2}) = f(x_{1} - \frac{\alpha}{h})$$
#
# j = 3
#
# $$\frac{1}{h^2}(U_{2} - 2U_{3}+ U_{4}) = f(x_{3})$$
#
# j = 5
#
# $$\frac{1}{h^2}(U_{4} - 2U_{5}+ U_{6}) = f(x_{5})$$
# .
# .
#
# j = m-1
#
# $$\frac{1}{h^2}(U_{m-2} - 2U_{m-1}+ U_{m}) = f(x_{m-1})$$
#
#
# EVEN
#
# j = 2
#
# $$\frac{1}{h^2}(U_{1} - 2U_{2}+ U_{3}) = f(x_{2})$$
# .
# .
# .
#
# j = m
#
# $$\frac{1}{h^2}(U - 2U_{m}) = f(x_{m})-\frac{\beta}{h}$$
#
# $$
# \frac{1}{h^2}
# \cdot
# \begin{bmatrix}
# -2& ...&...&0 & |& 1&...&...& 0\\
# 0& -2& 0 & ...& |& 0& 1& 0 & ...\\
# 0& ...& 0 & -2& |& 0& ...& 0 & 1 \\
# -& -& - & -& |& -& -& - &  -\\
# 1& ...&...&0 & |& -2&...&...& 0\\
# 0& 1& 0 & ...& |& 0& -2& 0 & ...\\
# 0& ...& 0 & 1& |& 0& ...& 0 & -2 \\
# \end{bmatrix}
#
#  \cdot
#
# \begin{bmatrix}
# U_{1}\\
# U_{3}\\
# ...\\
# U_{m-1}\\
# u_{2}\\
# ...\\
# U_{m}
# \end{bmatrix}
#
# =
#
# \begin{bmatrix}
# f(x_{1}) - \frac{\alpha}{u^{2}}\\
# f(x_{3})\\
# f(x_{5})
# ...\\
# f(x_{m-1})\\
# f(x_{2})\\
# ...
# f(x_{m}) - \frac{\beta}{u^{2}}\\
# \end{bmatrix} $$

# %% [markdown]
# form
#
# $$a(x) u^{"} + b(x)u^{'} + c(x)u = f$$
#
# $$a(x)\frac{U_{j-1} - 2U_j + U_{j+1}}{h^2} + b(x)u^{'}\frac{U_{j-1} - 2U_j + U_{j+1}}{2h} + c(x)U_{i} = f$$

# %% [markdown]
# # Ellipite PDEs
#
# a gerneral liptic PDE can be written as
#
# $$a_{1}\frac{\partial^{2} u}{\partial x^{2}} + a_{2}\frac{\partial^{2} u}{\partial y^{2}} + a_{4}\frac{\partial u}{\partial x}+a_{5}\frac{\partial u}{\partial y} + a_{6}u = f
